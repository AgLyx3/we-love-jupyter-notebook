# %% [markdown]
# # Local notebook agent example
# Edit the parameters, then inspect the downstream result.

# %%
values = [2, 4, 6]

# %%
total = sum(values)
print(f"Total: {total}")

# %%
average = total / len(values)
average
